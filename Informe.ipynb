# %% [markdown]
# Hola &#x1F600;
#
# Soy **Hesus Garcia**  como "Jesús" pero con H. Sé que puede ser confuso al principio, pero una vez que lo recuerdes, ¡nunca lo olvidarás! &#x1F31D;	. Como revisor de código de Practicum, estoy emocionado de examinar tus proyectos y ayudarte a mejorar tus habilidades en programación. si has cometido algún error, no te preocupes, pues ¡estoy aquí para ayudarte a corregirlo y hacer que tu código brille! &#x1F31F;. Si encuentro algún detalle en tu código, te lo señalaré para que lo corrijas, ya que mi objetivo es ayudarte a prepararte para un ambiente de trabajo real, donde el líder de tu equipo actuaría de la misma manera. Si no puedes solucionar el problema, te proporcionaré más información en la próxima oportunidad. Cuando encuentres un comentario,  **por favor, no los muevas, no los modifiques ni los borres**.
#
# Revisaré cuidadosamente todas las implementaciones que has realizado para cumplir con los requisitos y te proporcionaré mis comentarios de la siguiente manera:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# </br>
#
# **¡Empecemos!**  &#x1F680;

# %% [markdown]
# # Informe de solucion

# %% [markdown]
# Objetivo del Proyecto
# El objetivo de este proyecto es desarrollar un modelo de clasificación que prediga si un cliente ha cancelado su servicio (representado en la columna EndDate) en base a ciertas características del cliente, como los cargos mensuales (MonthlyCharges), los cargos totales (TotalCharges), el género (gender), y si el cliente es un ciudadano sénior (SeniorCitizen).
#
# Limpieza de Datos Faltantes:
#
# La columna TotalCharges tenía algunos valores faltantes que fueron llenados con 0.
# Varias otras columnas contenían valores faltantes ("No") que fueron rellenados con el valor 'No'.
# Codificación de la Variable Objetivo:
#
# La columna EndDate fue convertida a una variable binaria:
# 0 para clientes que no han cancelado (cuando el valor es 'No').
# 1 para clientes que sí han cancelado (cuando la columna contiene una fecha).
#
# Codificación de Variables Categóricas:
#
# La columna gender fue convertida en una variable numérica binaria utilizando pd.get_dummies(), donde los valores "Male" y "Female" fueron transformados en 0 y 1.
# Limpieza Adicional:
#
# Se reemplazaron posibles espacios vacíos o cadenas en las columnas de características con NaN y se forzó la conversión a numérico.
# Se eliminaron las filas que contenían valores nulos después del preprocesamiento para asegurar que los datos estuvieran listos para el entrenamiento.
#
# 3. Construcción del Modelo
# El modelo seleccionado para esta tarea es un RandomForestClassifier, que es un modelo de ensamblado de múltiples árboles de decisión. Este modelo es adecuado para tareas de clasificación y maneja bien las características numéricas y categóricas.
#
# Dividir los Datos
# Se dividieron los datos en un conjunto de entrenamiento y un conjunto de prueba utilizando la función train_test_split(), con un 80% de los datos para entrenamiento y un 20% para prueba. La variable objetivo es la columna EndDate.
#
# Características de entrada (X):
# MonthlyCharges
# TotalCharges
# gender (codificado)
# SeniorCitizen
# Variable objetivo (y):
# EndDate (codificado como 0 o 1).
#
# Evaluación del Modelo
# Una vez que el modelo fue entrenado, se realizaron predicciones sobre el conjunto de prueba. Los resultados de las predicciones se compararon con los valores reales de la variable objetivo, y se generó un informe de clasificación para evaluar el desempeño del modelo.
#
# 4. Resultados
# Los resultados obtenidos con el modelo Random Forest se evaluaron utilizando las métricas de precisión, recall, F1-score, y accuracy.
#
# Métricas de Evaluación
# El informe de clasificación incluye las siguientes métricas:
#
# Precision: Proporción de predicciones correctas entre los casos clasificados como positivos.
# Recall: Proporción de verdaderos positivos correctamente identificados.
# F1-Score: Media armónica entre la precisión y el recall.
# Accuracy: Porcentaje de predicciones correctas en general.
#
# Resultados Esperados
# Con este modelo de clasificación basado en un Random Forest, se espera que el desempeño sea evaluado en función del equilibrio entre precisión y recall, lo que es clave en contextos donde es importante evitar tanto falsos positivos como falsos negativos, dependiendo de los costos asociados a cada tipo de error.
#
# 5. Conclusiones
# Este modelo de Random Forest ha demostrado ser efectivo para clasificar la probabilidad de cancelación de un cliente, basado en sus características demográficas y financieras. Si bien el desempeño específico en términos de precisión, recall y F1-score dependerá de la calidad de los datos y los parámetros del modelo, este enfoque general puede ser útil para prever cancelaciones y ayudar a la empresa a tomar medidas preventivas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario final:</b><br>
# Felicidades por concluir el bootcamp de Tripleten con este proyecto impresionante. Tu habilidad para navegar desde la recopilación hasta el análisis avanzado de datos habla de tu compromiso y habilidad técnica.
#
# Para potenciar aún más tu trayectoria, considera estos aspectos clave:
#
# <ul>
#   <li><strong>Deployment de Modelos</strong>: Aprende a implementar modelos en entornos de producción. Conocer herramientas como Docker y plataformas como AWS, Google Cloud, o Azure te abrirá muchas puertas.</li>
#   <li><strong>Innovación en Modelos</strong>: No te detengas aquí. Experimenta con nuevas técnicas y modelos para seguir mejorando tus resultados. La práctica continua es esencial en el campo del Machine Learning.</li>
#   <li><strong>Desarrollo de Habilidades Interpersonales</strong>: Aprovecha LinkedIn para mostrar tu trabajo, participa activamente en comunidades, y no dudes en compartir tus conocimientos y aprendizajes. Esto te ayudará a construir una red sólida.</li>
#   <li><strong>Participación Comunitaria</strong>: Engánchate con la comunidad a través de eventos y conferencias. Aprenderás mucho y podrás conectar con profesionales que comparten tus intereses.</li>
# </ul>
#
# Felicidades una vez más por tu logro en el bootcamp de Tripleten. Estoy emocionado de ver adónde te llevarán tus habilidades y ambición. ¡Adelante, el futuro es brillante! 🌟🚀
# </div>
